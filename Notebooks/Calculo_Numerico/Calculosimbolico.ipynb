# %% [markdown]
# # Calculo Simbólico con Sympy

# %% [markdown]
# ### Importamos las bibliotecas necesarias

# %%
from sympy import init_session

init_session
# Out:
# <function sympy.interactive.session.init_session>

# %%
init_session(use_latex=True)
# Out:
# ---------------------------------------------------------------------------
# MultipleInstanceError                     Traceback (most recent call last)
# <ipython-input-2-21358163c2df> in <module>()
# ----> 1 init_session(use_latex=True)
#
# /usr/local/lib/python3.6/dist-packages/sympy/interactive/session.py in init_session(ipython, pretty_print, order, use_unicode, use_latex, quiet, auto_symbols, auto_int_to_Integer, str_printer, pretty_printer, latex_printer, argv)
#     431     else:
#     432         ip = init_ipython_session(argv=argv, auto_symbols=auto_symbols,
# --> 433             auto_int_to_Integer=auto_int_to_Integer)
#     434
#     435         if V(IPython.__version__) >= '0.11':
#
# /usr/local/lib/python3.6/dist-packages/sympy/interactive/session.py in init_ipython_session(argv, auto_symbols, auto_int_to_Integer)
#     262         # don't draw IPython banner during initialization:
#     263         app.display_banner = False
# --> 264         app.initialize(argv)
# ...

# %%
# Creando simbolos
a=symbols('a')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-380ff50fc530> in <module>()
#       1 # Creando simbolos
# ----> 2 a=symbols('a')
#
# NameError: name 'symbols' is not defined

# %%
# numeros especiales
(a+pi)**2
# Out:
#        2
# (a + π)

# %%
# La unidad imaginaria
1+2*I
# Out:
# 1 + 2⋅ⅈ

# %%
# Numero e
E**2
# Out:
#  2
# ℯ

# %%
type(a)
# Out:
# sympy.core.symbol.Symbol

# %%
# creacion de simbolos
alpha,beta=symbols('alpha,beta')

# %%
alpha
# Out:
# α

# %%
# creando simbolas reales
x,y,z,t=symbols('x,y,z,t')
x,y,z,t
# Out:
# (x, y, z, t)

# %%
x.assumptions0
# Out:
# {'commutative': True}

# %%
w=symbols('w',real=True,positive=True)

# %%
w.assumptions0

# %% [markdown]
# ## Expresiones
# consideremos la expresion $cos(x)^2+sen(x)^2$

# %%
cos(x)**2+sin(x)**2
# Out:
#    2         2
# sin (x) + cos (x)

# %%
#simplificando la expresion
simplify(_23)
# Out:
# 1

# %%
sqrt(z**2)
# Out:
#    ____
#   ╱  2
# ╲╱  z

# %%
simplify(_27)
# Out:
#    ____
#   ╱  2
# ╲╱  z

# %%
y=symbols('y',real=True)
simplify(sqrt(y**2))
# Out:
# │y│

# %% [markdown]
# ### En algunos casos es necesario substituir una variable por otra o por un valor, se usa el comando .subs

# %%
_23.subs(x,1+z**2)
# Out:
#    2⎛ 2    ⎞      2⎛ 2    ⎞
# sin ⎝z  + 1⎠ + cos ⎝z  + 1⎠

# %% [markdown]
# ### substituir varaias variables

# %%
(sin(x)**2+cos(y)**2).subs({x:1+z,y:1-z})
# Out:
#    2             2
# sin (z + 1) + cos (z - 1)

# %% [markdown]
# ### substituir por funciones

# %%
sin(x).replace(sin,exp)
# Out:
#  x
# ℯ

# %% [markdown]
# ### Particularizar en un valor

# %%
(tan(x)+3*x).subs(x,pi/4)
# Out:
#     3⋅π
# 1 + ───
#      4

# %% [markdown]
# ### Si se quiere el valor numérico

# %%
_44.evalf()
# Out:
# 3.35619449019234

# %%
N(_44)
# Out:
# 3.35619449019234

# %% [markdown]
# ## Derivadas e Integrales

# %%
expr=cos(x)
expr
# obtenemos la primera derivada
expr.diff(x)
# Out:
# -sin(x)

# %% [markdown]
# #### La derivada cuarta

# %%
expr.diff(x,4)
# Out:
# cos(x)

# %% [markdown]
# #### varias variables

# %%
expr=y*exp(2*x)+y/(x**2+y**3)
expr
# Out:
#    2⋅x      y
# y⋅ℯ    + ───────
#           2    3
#          x  + y

# %%
expr.diff(x,2,y,3)
# Out:
#      ⎛        2  6        2  3         2           6          3     ⎞
#      ⎜  1080⋅x ⋅y    648⋅x ⋅y      48⋅x       108⋅y       81⋅y      ⎟
# 12⋅y⋅⎜- ────────── + ────────── - ─────── + ────────── - ─────── + 8⎟
#      ⎜           3            2    2    3            2    2    3    ⎟
#      ⎜  ⎛ 2    3⎞    ⎛ 2    3⎞    x  + y    ⎛ 2    3⎞    x  + y     ⎟
#      ⎝  ⎝x  + y ⎠    ⎝x  + y ⎠              ⎝x  + y ⎠               ⎠
# ─────────────────────────────────────────────────────────────────────
#                                        3
#                               ⎛ 2    3⎞
#                               ⎝x  + y ⎠

# %% [markdown]
# #### Dejaral indicada

# %%
Derivative(expr,y)
# Out:
# ∂ ⎛   2⋅x      y   ⎞
# ──⎜y⋅ℯ    + ───────⎟
# ∂y⎜          2    3⎟
#   ⎝         x  + y ⎠

# %% [markdown]
# ### Integración
# $$\int{cos(x)^2dx}$$

# %% [markdown]
# $$\int\frac{1}{sin(x)}dx$$

# %% [markdown]
# $$ \int\frac{1}{(x^2+a^2)^3}dx$$

# %%
(1/(x**2+a**2)**3)

# %%
integrate(cos(x)**2,x)
# Out:
# x   sin(x)⋅cos(x)
# ─ + ─────────────
# 2         2

# %%
(1/sin(x)).integrate()
# Out:
# log(cos(x) - 1)   log(cos(x) + 1)
# ─────────────── - ───────────────
#        2                 2

# %%
(1/(x**2+a**2)**3)
# Out:
#     1
# ──────────
#          3
# ⎛ 2    2⎞
# ⎝a  + x ⎠

# %%
integrate(1/(x**2+a**2)**3,x)
# Out:
#                               3⋅ⅈ⋅log(-ⅈ⋅a + x)   3⋅ⅈ⋅log(ⅈ⋅a + x)
#          2        3         - ───────────────── + ────────────────
#       5⋅a ⋅x + 3⋅x                    16                 16
# ───────────────────────── + ──────────────────────────────────────
#    8       6  2      4  4                      5
# 8⋅a  + 16⋅a ⋅x  + 8⋅a ⋅x                      a
